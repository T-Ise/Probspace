# %% [markdown]
# # データ読み込み、シリアライズ
# > train_data, test_dataをシリアライズし、pandas.Dataframe型に置き換える

# %%
import pandas as pd
import scipy as sc
import numpy as np
import sklearn
import pickle
import pathlib as Path
import matplotlib.pyplot as plt
import japanize_matplotlib
import seaborn as sb
sb.set(font='IPAexGothic')

import multiprocessing
import itertools
import collections
import datetime
import gc

from tqdm._tqdm_notebook import tqdm

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

data_path = Path.Path("../data")
img_path = Path.Path("../img")
result_path = Path.Path("../result")

prefix = 'ana001'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`

# %% [markdown]
# ## データ読み込み
# > 今回のjsonファイルは1行1データ
# > 1行の文字列をdictに直すのは json.loads() を使用する
# > versions列のみ、list[dict{}, ...] 形式となっており、そのままDF化すると複数行定義となってしまう為、暫定的にlistで囲っておく

# %%
import json

# jsonファイルから一行ずつ読み出す関数(generator)
def get_data_iter(fpath):
    
    # 対象のパスを開く
    with open(fpath, 'r') as f:
        
        # 一行ごとに切り出す
        for l in f:
            
            # 一行ごとに返却
            yield l
            
# 値が複数のリストになっているものを、入れ子にする関数
def modify_data(data):
    
    # 'versions'列がある場合
    if data.get('versions') is not None:
    
        # 'versions'列を入れ子にする(※lenを1にする)
        data['versions'] = [data['versions']]
    
    return data

# 対象のjsonファイルをDF化する
def json_to_df(path):
    
    return pd.DataFrame([modify_data(json.loads(line)) for line in get_data_iter(path)])

# %%
# 訓練データ読み込み
train_df = json_to_df(data_path / 'train_data.json')

# pickle化しておく
train_df.to_pickle(data_path / 'train_df.pkl')

train_df
# Out:
#                     id                     submitter  \
# 0       hep-ph/9902295               Michael Kraemer
# 1            1403.7138                      Aigen Li
# 2            1405.5857             Michael Mortonson
# 3           1807.01034  Evangelos Thomas Karamatskos
# 4           1905.05921                   Juanjuan Gu
# ...                ...                           ...
# 851519      1708.06097                  Haim Diamant
# 851520      1904.07627                 Chonglong Liu
# 851521      1507.01140                Othman Benomar
# 851522      2006.03674                 Sukriti Manna
# 851523       1001.1423                  Daniel Kabat
#
#                                                   authors  \
# 0       Mark E. Hayes (University College London) and ...
# 1       Qi Li, S.L. Liang, Aigen Li (University of Mis...
# 2                   Michael J. Mortonson, Uro\v{s} Seljak
# 3       Evangelos T. Karamatskos, Sebastian Raabe, Ter...
# 4                                Juanjuan Gu and Yun Jing
# ...                                                   ...
# 851519                       Rony Granek and Haim Diamant
# 851520                C. L. Liu, Xiao-Dong Yu, D. M. Tong
# 851521  O. Benomar, M. Takata, H. Shibahashi, T. Ceill...
# 851522  Troy D Loeffler, Sukriti Manna, Tarak K Patra,...
# 851523  Brian Greene, Daniel Kabat, Janna Levin, and D...
#
#                                                     title  \
# 0                        Heavy-Flavour Production at HERA
# 1       Spectropolarimetric Constraints on the Nature ...
# 2       A joint analysis of Planck and BICEP2 B modes ...
# 3       Molecular movie of ultrafast coherent rotation...
# 4       A Modified Mixed Domain Method for Modeling Ac...
# ...                                                   ...
# 851519  Membrane undulations in a structured fluid: Un...
# 851520       Flag Additivity in Quantum Resource Theories
# 851521  Nearly-uniform internal rotation of solar-like...
# 851522  Active Learning A Neural Network Model For Gol...
# 851523  A bulk inflaton from large volume extra dimens...
#
#                                                  comments  \
# 0       LaTeX, 21 pages, 13 Postscript figures. Summar...
# 1       5 pages, 2 figures; accepted for publication i...
# 2       13 pages, 4 figures; submitted to JCAP; refere...
# 3                                               9 Figures
# 4                                                    None
# ...                                                   ...
# 851519                                           10 pages
# 851520                                            6 pages
# 851521                                  Accepted to MNRAS
# 851522                                               None
# 851523  21 pages, LaTeX, 2 pdf figures. v2: additional...
#
#                           journal-ref                             doi  \
# 0           J.Phys.G25:1477-1493,1999      10.1088/0954-3899/25/7/332
# 1                                None           10.1093/mnrasl/slu021
# 2                     JCAP10(2014)035   10.1088/1475-7516/2014/10/035
# 3          Nat Commun 10, 3364 (2019)      10.1038/s41467-019-11122-y
# 4                                None              10.1121/10.0001454
# ...                               ...                             ...
# 851519   Eur. Phys. J. E 41, 1 (2018)      10.1140/epje/i2018-11607-x
# 851520  Phys. Rev. A 99, 042322(2019)      10.1103/PhysRevA.99.042322
# 851521                           None           10.1093/mnras/stv1493
# 851522                           None          10.1002/cctc.202000774
# 851523    Phys.Lett.B694:485-490,2011  10.1016/j.physletb.2010.10.036
#
#                            report-no  \
# 0       CERN-TH/99-30, UCL/HEP 99-03
# 1                               None
# 2                               None
# 3                               None
# 4                               None
# ...                              ...
# 851519                          None
# 851520                          None
# 851521                          None
# 851522                          None
# 851523                          None
#
#                                       categories  \
# 0                                  hep-ph hep-ex
# 1                                    astro-ph.GA
# 2                astro-ph.CO gr-qc hep-ph hep-th
# 3       physics.chem-ph physics.atom-ph quant-ph
# 4                 physics.med-ph physics.comp-ph
# ...                                          ...
# 851519                             cond-mat.soft
# 851520                                  quant-ph
# 851521                               astro-ph.SR
# 851522         physics.comp-ph cond-mat.mtrl-sci
# 851523                                    hep-th
#
#                                                   license  \
# 0                                                    None
# 1       http://arxiv.org/licenses/nonexclusive-distrib...
# 2       http://arxiv.org/licenses/nonexclusive-distrib...
# 3       http://arxiv.org/licenses/nonexclusive-distrib...
# 4       http://arxiv.org/licenses/nonexclusive-distrib...
# ...                                                   ...
# 851519  http://arxiv.org/licenses/nonexclusive-distrib...
# 851520  http://arxiv.org/licenses/nonexclusive-distrib...
# 851521  http://arxiv.org/licenses/nonexclusive-distrib...
# 851522  http://arxiv.org/licenses/nonexclusive-distrib...
# 851523  http://arxiv.org/licenses/nonexclusive-distrib...
#
#                                                  abstract  \
# 0         We review the theoretical and experimental s...
# 1         While it is well recognized that interstella...
# 2         We analyze BICEP2 and Planck data using a mo...
# 3         Recording molecular movies on ultrafast time...
# 4         In this paper, phase correction and amplitud...
# ...                                                   ...
# 851519    The dynamics of membrane undulations inside ...
# 851520    Quantum resource theories offer a powerful f...
# 851521    The rotation rates in the deep interior and ...
# 851522    Small metal clusters are of fundamental scie...
# 851523    The universe may have extra spatial dimensio...
#
#                                                  versions update_date  \
# 0       [[{'version': 'v1', 'created': 'Wed, 10 Feb 19...  2008-11-26
# 1       [[{'version': 'v1', 'created': 'Thu, 27 Mar 20...  2015-06-19
# 2       [[{'version': 'v1', 'created': 'Thu, 22 May 20...  2014-10-17
# 3       [[{'version': 'v1', 'created': 'Tue, 3 Jul 201...  2020-05-19
# 4       [[{'version': 'v1', 'created': 'Wed, 15 May 20...  2020-07-15
# ...                                                   ...         ...
# 851519  [[{'version': 'v1', 'created': 'Mon, 21 Aug 20...  2018-02-20
# 851520  [[{'version': 'v1', 'created': 'Tue, 16 Apr 20...  2019-04-17
# 851521  [[{'version': 'v1', 'created': 'Sat, 4 Jul 201...  2015-08-06
# 851522  [[{'version': 'v1', 'created': 'Fri, 5 Jun 202...  2020-07-21
# 851523  [[{'version': 'v1', 'created': 'Sun, 10 Jan 20...  2011-06-27
#
#                                            authors_parsed doi_cites  cites
# 0       [[Hayes, Mark E., , University College London]...         1    NaN
# 1       [[Li, Qi, , University of Missouri], [Liang, S...         8    7.0
# 2           [[Mortonson, Michael J., ], [Seljak, Uroš, ]]       122  188.0
# 3       [[Karamatskos, Evangelos T., ], [Raabe, Sebast...         6    8.0
# 4                       [[Gu, Juanjuan, ], [Jing, Yun, ]]         0    NaN
# ...                                                   ...       ...    ...
# 851519              [[Granek, Rony, ], [Diamant, Haim, ]]         0    NaN
# 851520  [[Liu, C. L., ], [Yu, Xiao-Dong, ], [Tong, D. ...         2    NaN
# 851521  [[Benomar, O., ], [Takata, M., ], [Shibahashi,...        42    NaN
# 851522  [[Loeffler, Troy D, ], [Manna, Sukriti, ], [Pa...         0    NaN
# 851523  [[Greene, Brian, ], [Kabat, Daniel, ], [Levin,...         3    NaN
#
# [851524 rows x 16 columns]

# %%
# テストデータ読み込み
test_df = json_to_df(data_path / 'test_data.json')

# pickle化しておく
test_df.to_pickle(data_path / 'test_df.pkl')

test_df
# Out:
#                      id          submitter  \
# 0            1605.00995   Simonetta Abenda
# 1             1206.6911      Hanqing Zheng
# 2      cond-mat/0504055       Haim Diamant
# 3      astro-ph/9907297  Tod E. Strohmayer
# 4             1104.5407       Lie-Wen Chen
# ...                 ...                ...
# 59079         1210.4112      Hamish Gordon
# 59080        1701.03465      In Sung  Jang
# 59081        1709.10428      Vincent Beaud
# 59082     gr-qc/9803020        Kengo Maeda
# 59083  cond-mat/0512492  Bartlomiej Dybiec
#
#                                                  authors  \
# 0                                       Simonetta Abenda
# 1        L. Y. Dai, Meng Shi, Guang-Yi Tang, H. Q. Zheng
# 2       B. Lin, M. Meron, B. Cui, S. A. Rice, H. Diamant
# 3                                      Tod E. Strohmayer
# 4                            Lie-Wen Chen, Jian-Zhong Gu
# ...                                                  ...
# 59079  LHCb collaboration: R. Aaij, C. Abellan Beteta...
# 59080  Myung Gyoon Lee, In Sung Jang, Rachael Beaton,...
# 59081                    Vincent Beaud and Simone Warzel
# 59082  Kengo Maeda, Akihiro Ishibashi, and Makoto Narita
# 59083          B. Dybiec, E. Gudowska-Nowak, P. H\"anggi
#
#                                                    title  \
# 0      On a family of KP multi-line solitons associat...
# 1                               On the Nature of X(4260)
# 2              From random walk to single-file diffusion
# 3      Spin Down of Pulsations in the Cooling Tail of...
# 4      Correlations between the nuclear breathing mod...
# ...                                                  ...
# 59079  Measurement of the D+/- production asymmetry i...
# 59080  The Carnegie-Chicago Hubble Program: Discovery...
# 59081  Bounds on the entanglement entropy of droplet ...
# 59082    Chronology Protection and Non-Naked Singularity
# 59083  Levy--Brownian motion on finite intervals: Mea...
#
#                                                 comments  \
# 0      48 pages, 5 figures. Revised manuscript. Added...
# 1      Refined analysis with new experimental data in...
# 2                                     4 pages, 4 figures
# 3      16 pages, AASTEX preprint with 7 embedded figu...
# 4      9 pages, 6 figures. Discussions and references...
# ...                                                  ...
# 59079                                12 pages, 5 figures
# 59080  6 pages, 4 figures, 1 table, accepted for publ...
# 59081                                           15 pages
# 59082  17 pages including 3 eps figures. Accepted for...
# 59083                                9 pages, 13 figures
#
#                               journal-ref                             doi  \
# 0      J. Geom. Phys. 119 (2017), 112-138  10.1016/j.geomphys.2017.04.005
# 1          Phys. Rev. D 92, 014020 (2015)      10.1103/PhysRevD.92.014020
# 2         Phys Rev Lett 94, 216001 (2005)   10.1103/PhysRevLett.94.216001
# 3                                    None                  10.1086/312258
# 4                  J.Phys.G39:035104,2012   10.1088/0954-3899/39/3/035104
# ...                                   ...                             ...
# 59079   Phys. Lett. B. 718 (2013) 902-907  10.1016/j.physletb.2012.11.038
# 59080                                None     10.3847/2041-8213/835/2/L27
# 59081                                None               10.1063/1.5007035
# 59082  Class.Quant.Grav.15:1637-1651,1998      10.1088/0264-9381/15/6/018
# 59083      Phys. Rev. E 73, 046104 (2006)      10.1103/PhysRevE.73.046104
#
#                                       report-no  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
# ...                                         ...
# 59079  LHCb-PAPER-2012-026; CERN-PH-EP-2012-305
# 59080                                      None
# 59081                                      None
# 59082                      TIT/HEP-377/COSMO-87
# 59083                                      None
#
#                                             categories  \
# 0                                      math-ph math.MP
# 1                                        hep-ph hep-ex
# 2      cond-mat.soft cond-mat.mtrl-sci physics.chem-ph
# 3                                             astro-ph
# 4                          nucl-th astro-ph.SR nucl-ex
# ...                                                ...
# 59079                                           hep-ex
# 59080                                      astro-ph.GA
# 59081                                  math-ph math.MP
# 59082                                            gr-qc
# 59083                cond-mat.stat-mech cond-mat.other
#
#                                                  license  \
# 0      http://arxiv.org/licenses/nonexclusive-distrib...
# 1      http://arxiv.org/licenses/nonexclusive-distrib...
# 2                                                   None
# 3                                                   None
# 4      http://arxiv.org/licenses/nonexclusive-distrib...
# ...                                                  ...
# 59079        http://creativecommons.org/licenses/by/3.0/
# 59080  http://arxiv.org/licenses/nonexclusive-distrib...
# 59081  http://arxiv.org/licenses/nonexclusive-distrib...
# 59082                                               None
# 59083                                               None
#
#                                                 abstract  \
# 0        We classify the soliton data in the totally ...
# 1        We study the property of $X(4260)$ resonance...
# 2        We report an experimental study of diffusion...
# 3        We report the discovery with the proportiona...
# 4        Based on microscopic Hartree-Fock + random p...
# ...                                                  ...
# 59079    The asymmetry in the production cross-sectio...
# 59080    Ultra-faint dwarf galaxies (UFDs) are the fa...
# 59081    We consider a class of one-dimensional quant...
# 59082    We test the chronology protection conjecture...
# 59083    We present the analysis of the first passage...
#
#                                                 versions update_date  \
# 0      [[{'version': 'v1', 'created': 'Tue, 3 May 201...  2019-06-27
# 1      [[{'version': 'v1', 'created': 'Thu, 28 Jun 20...  2015-07-22
# 2      [[{'version': 'v1', 'created': 'Sun, 3 Apr 200...  2007-05-23
# 3      [[{'version': 'v1', 'created': 'Wed, 21 Jul 19...  2009-10-31
# 4      [[{'version': 'v1', 'created': 'Thu, 28 Apr 20...  2012-03-27
# ...                                                  ...         ...
# 59079  [[{'version': 'v1', 'created': 'Mon, 15 Oct 20...  2012-12-20
# 59080  [[{'version': 'v1', 'created': 'Thu, 12 Jan 20...  2017-02-08
# 59081  [[{'version': 'v1', 'created': 'Fri, 29 Sep 20...  2018-02-14
# 59082  [[{'version': 'v1', 'created': 'Thu, 5 Mar 199...  2011-07-19
# 59083  [[{'version': 'v1', 'created': 'Tue, 20 Dec 20...  2020-03-16
#
#                                           authors_parsed doi_cites
# 0                                [[Abenda, Simonetta, ]]         5
# 1      [[Dai, L. Y., ], [Shi, Meng, ], [Tang, Guang-Y...        23
# 2      [[Lin, B., ], [Meron, M., ], [Cui, B., ], [Ric...        93
# 3                               [[Strohmayer, Tod E., ]]        24
# 4                [[Chen, Lie-Wen, ], [Gu, Jian-Zhong, ]]        12
# ...                                                  ...       ...
# 59079  [[LHCb collaboration, , ], [Aaij, R., ], [Bete...        22
# 59080  [[Lee, Myung Gyoon, ], [Jang, In Sung, ], [Bea...         5
# 59081           [[Beaud, Vincent, ], [Warzel, Simone, ]]         6
# 59082  [[Maeda, Kengo, ], [Ishibashi, Akihiro, ], [Na...         5
# 59083  [[Dybiec, B., ], [Gudowska-Nowak, E., ], [Häng...        71
#
# [59084 rows x 15 columns]

# %% [markdown]
# - memo
# > 各所にNone文字列があり、nanと同義
# > idは統一的でない -> indexを新たにidとしなおしても良い
# > authorsはlist化されていない
# > commentsから数値を抜き出せる
# > jornal-ref(掲載誌)から出版年等を割り出せる
# > doi, は別IDのようなので、必要がない?
# > report-noは"大学のプレプリントサーバー等による識別子"とある、サーバーによって被引用数に違いがある?
# > categoriesはサーバーのシステム上のカテゴリ
# > licenceによって被引用数に違いがある？
# > abstが一番のキモ?
# > update_dateは更新日時
# > authors_parsedには著者名がlistのlistになっている
# > doi_citesは低精度被引用数、citiesがない場合は考慮しなければならない
